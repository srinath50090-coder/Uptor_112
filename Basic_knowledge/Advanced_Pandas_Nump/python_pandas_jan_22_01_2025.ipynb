# %%
import pandas as pd

# %%
var = [4,6,8]
print(var)
# Out:
# [4, 6, 8]

# %%
var = pd.DataFrame(var)
print(var)
# Out:
#    0
# 0  4
# 1  6
# 2  8

# %%
var = pd.DataFrame(var,columns=["a"],index=["a","b","C"])
print(var)
# Out:
#     a
# a NaN
# b NaN
# C NaN

# %%
pd.read_csv("diamonds.csv")
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df.shape
# Out:
# (53940, 11)

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df.drop(columns="Unnamed: 0", axis=1,inplace=True)

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
df['carat']
# Out:
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64

# %%
df[['carat']]
# Out:
#        carat
# 0       0.23
# 1       0.21
# 2       0.23
# 3       0.29
# 4       0.31
# ...      ...
# 53935   0.72
# 53936   0.72
# 53937   0.70
# 53938   0.86
# 53939   0.75
#
# [53940 rows x 1 columns]

# %%
df.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
df.tail(10)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53930   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53932   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
# 53933   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72  3.49
# 53934   0.72    Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
df[0:90]
# Out:
#     carat      cut color clarity  depth  table  price     x     y     z
# 0    0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..    ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 85   0.24  Premium     G    VVS1   62.3   59.0    554  3.95  3.92  2.45
# 86   0.24  Premium     H    VVS1   61.2   58.0    554  4.01  3.96  2.44
# 87   0.24  Premium     H    VVS1   60.8   59.0    554  4.02  4.00  2.44
# 88   0.24  Premium     H    VVS2   60.7   58.0    554  4.07  4.04  2.46
# 89   0.32  Premium     I     SI1   62.9   58.0    554  4.35  4.33  2.73
#
# [90 rows x 10 columns]

# %%
pd.set_option("display.max_row",None)
df.loc[0:90]
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# ...

# %% [markdown]
# df.loc[0:90,["carat","cut"]]

# %%
df.iloc[0:90,[1,4,6]]
# Out:
#           cut  depth  price
# 0       Ideal   61.5    326
# 1     Premium   59.8    326
# 2        Good   56.9    327
# 3     Premium   62.4    334
# 4        Good   63.3    335
# 5   Very Good   62.8    336
# 6   Very Good   62.3    336
# 7   Very Good   61.9    337
# 8        Fair   65.1    337
# 9   Very Good   59.4    338
# 10       Good   64.0    339
# 11      Ideal   62.8    340
# 12    Premium   60.4    342
# 13      Ideal   62.2    344
# 14    Premium   60.2    345
# 15    Premium   60.9    345
# 16      Ideal   62.0    348
# 17       Good   63.4    351
# 18       Good   63.8    351
# 19  Very Good   62.7    351
# 20       Good   63.3    351
# 21  Very Good   63.8    352
# 22  Very Good   61.0    353
# 23  Very Good   59.4    353
# 24  Very Good   58.1    353
# 25  Very Good   60.4    354
# 26    Premium   62.5    355
# 27  Very Good   62.2    357
# 28  Very Good   60.5    357
# 29  Very Good   60.9    357
# 30  Very Good   60.0    402
# 31  Very Good   59.8    402
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
# 30       False
# 31       False
# 32       False
# 33       False
# 34       False
# 35       False
# 36       False
# 37       False
# 38       False
# 39       False
# 40       False
# 41       False
# 42       False
# 43       False
# 44       False
# 45       False
# 46       False
# 47       False
# 48       False
# 49       False
# 50       False
# 51       False
# 52       False
# 53       False
# 54       False
# 55       False
# 56       False
# 57       False
# ...

# %%
df.duplicated().sum()
# Out:
# 146

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.duplicated().value_counts()
# Out:
# False    53794
# True       146
# Name: count, dtype: int64

# %%
df.duplicated(subset=['carat','cut'],keep=False).value_counts()
# Out:
# True     53772
# False      168
# Name: count, dtype: int64

# %%
df.drop_duplicates(inplace=True)
df.duplicated().value_counts()
# Out:
# False    53794
# Name: count, dtype: int64

# %%
df['cut'].count()
# Out:
# 53794

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        21488
# Premium      13748
# Very Good    12069
# Good          4891
# Fair          1598
# Name: count, dtype: int64

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
df['cut'].nunique()
# Out:
# 5

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# !pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
label_encoding_object = LabelEncoder()
df['cut'] = label_encoding_object.fit_transform(df['cut'])
print(df.head(20))
# Out:
#     carat  cut color clarity  depth  table  price     x     y     z
# 0    0.23    2     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    3     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23    1     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    3     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31    1     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24    4     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24    4     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26    4     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22    0     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23    4     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30    1     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23    2     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12   0.22    3     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# ...

# %%
# Out:
# 0        2
# 1        3
# 2        1
# 3        3
# 4        1
# 5        4
# 6        4
# 7        4
# 8        0
# 9        4
# 10       1
# 11       2
# 12       3
# 13       2
# 14       3
# 15       3
# 16       2
# 17       1
# 18       1
# 19       4
# 20       1
# 21       4
# 22       4
# 23       4
# 24       4
# 25       4
# 26       3
# 27       4
# 28       4
# 29       4
# 30       4
# 31       4
# 32       4
# 33       4
# 34       4
# 35       1
# 36       1
# 37       1
# 38       4
# 39       2
# 40       2
# 41       2
# 42       1
# 43       1
# 44       1
# 45       3
# 46       4
# 47       1
# 48       4
# 49       4
# 50       4
# 51       2
# 52       2
# 53       3
# 54       3
# 55       2
# 56       3
# 57       4
# 58       4
# 59       1
# 60       2
# 61       3
# 62       2
# 63       2
# 64       3
# 65       2
# 66       2
# 67       4
# 68       3
# 69       3
# 70       4
# 71       4
# 72       3
# 73       3
# 74       1
# 75       4
# ...

# %%
df['color'].value_counts()
# Out:
# color
# G    11262
# E     9776
# F     9520
# H     8272
# D     6755
# I     5407
# J     2802
# Name: count, dtype: int64

# %%
mapping_data = {"G":11,"E":111,"F":1000,"H":400,"D":90,"I":88,"J":77}
df['color'] = df['color'].map(mapping_data)
df.head(20)
# Out:
#     carat  cut  color clarity  depth  table  price     x     y     z
# 0    0.23    2    111     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    3    111     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23    1    111     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    3     88     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31    1     77     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24    4     77    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24    4     88    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26    4    400     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22    0    111     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23    4    400     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30    1     77     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23    2     77     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12   0.22    3   1000     SI1   60.4   61.0    342  3.88  3.84  2.33
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
ordinal_encoder_object = OrdinalEncoder()
df['clarity'] = ordinal_encoder_object.fit_transform(df[['clarity']])
df.head(20)
# Out:
#     carat  cut  color  clarity  depth  table  price     x     y     z
# 0    0.23    2    111      3.0   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    3    111      2.0   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23    1    111      4.0   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    3     88      5.0   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31    1     77      3.0   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24    4     77      7.0   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24    4     88      6.0   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26    4    400      2.0   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22    0    111      5.0   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23    4    400      4.0   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30    1     77      2.0   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23    2     77      4.0   62.8   56.0    340  3.93  3.90  2.46
# ...

# %%
df1 = pd.read_csv("diamonds.csv")
df1.head(10)
df1.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         1
# cut           2
# color         0
# clarity       1
# depth         0
# table         0
# price         1
# x             0
# y             2
# z             1
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         1
# cut           2
# color         0
# clarity       1
# depth         0
# table         0
# price         1
# x             0
# y             2
# z             1
# dtype: int64

# %%
df1.isnull().sum().sum()
# Out:
# 8

# %%
df1.dropna(inplace=True)
df1.isnull().sum().sum()
# Out:
# 0

# %%
pd.set_option("display.width",1000)
df1.reset_index(drop=True,inplace=True)
print(df1.head(20))
# Out:
#     Unnamed: 0  carat        cut color clarity  depth  table  price     x     y     z
# 0            3   0.23       Good     E     VS1   56.9   65.0  327.0  4.05  4.07  2.31
# 1            5   0.31       Good     J     SI2   63.3   58.0  335.0  4.34  4.35  2.75
# 2            6   0.24  Very Good     J    VVS2   62.8   57.0  336.0  3.94  3.96  2.48
# 3            7   0.24  Very Good     I    VVS1   62.3   57.0  336.0  3.95  3.98  2.47
# 4            8   0.26  Very Good     H     SI1   61.9   55.0  337.0  4.07  4.11  2.53
# 5            9   0.22       Fair     E     VS2   65.1   61.0  337.0  3.87  3.78  2.49
# 6           10   0.23  Very Good     H     VS1   59.4   61.0  338.0  4.00  4.05  2.39
# 7           11   0.30       Good     J     SI1   64.0   55.0  339.0  4.25  4.28  2.73
# 8           12   0.23      Ideal     J     VS1   62.8   56.0  340.0  3.93  3.90  2.46
# 9           13   0.22    Premium     F     SI1   60.4   61.0  342.0  3.88  3.84  2.33
# ...

# %%
df2 = pd.read_csv("diamonds.csv")
df2.head(10)
from sklearn.impute import SimpleImputer
df2["carat"] = SimpleImputer(strategy="mean").fit_transform(df2[['carat']])
df2.head(10)
# Out:
#    Unnamed: 0    carat        cut color clarity  depth  table  price     x     y     z
# 0           1  0.79795        NaN     E     SI2   61.5   55.0  326.0  3.95  3.98  2.43
# 1           2  0.21000        NaN     E     SI1   59.8   61.0  326.0  3.89   NaN   NaN
# 2           3  0.23000       Good     E     VS1   56.9   65.0  327.0  4.05  4.07  2.31
# 3           4  0.29000    Premium     I     NaN   62.4   58.0    NaN  4.20   NaN  2.63
# 4           5  0.31000       Good     J     SI2   63.3   58.0  335.0  4.34  4.35  2.75
# 5           6  0.24000  Very Good     J    VVS2   62.8   57.0  336.0  3.94  3.96  2.48
# 6           7  0.24000  Very Good     I    VVS1   62.3   57.0  336.0  3.95  3.98  2.47
# 7           8  0.26000  Very Good     H     SI1   61.9   55.0  337.0  4.07  4.11  2.53
# 8           9  0.22000       Fair     E     VS2   65.1   61.0  337.0  3.87  3.78  2.49
# 9          10  0.23000  Very Good     H     VS1   59.4   61.0  338.0  4.00  4.05  2.39
